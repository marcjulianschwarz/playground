# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np

# %%
labels = ["Label 1", "Label 2", "Label 3", "Label 4", "Label 5"]
labels.append(labels[0])

length = 100

data = [
    [np.sin(i*0.06) for i in range(0, length)], 
    [np.cos(i*0.06) for i in range(0, length)], 
    [np.sin(i*0.06) for i in range(0, length)],
    [np.cos(i*0.06) for i in range(0, length)],
    [np.sin(i*0.06) for i in range(0, length)]
    ]
data.append(data[0])

# Get len(labels) equal distance points on a circle
label_loc = np.linspace(0, 2*np.pi, num=len(labels))

fig, ax = plt.subplots(figsize=(10, 10), subplot_kw={'projection': 'polar'})

# Init 
radar_ln = ax.plot(label_loc, [d[0] for d in data], label="Legend")

ax.set_rmax(2)
ax.set_rmin(-2)

#ax.grid(False)
#ax.set_xticks([])
#ax.set_yticks([])
#ax.set_thetagrids(np.degrees(label_loc), labels=labels)
ax.legend(loc="lower left", bbox_to_anchor=(0.95, 0.95))

# %%
def animate(i, radar_ln, label_loc, data):
    radar_ln[0].set_data(label_loc, [d[i] for d in data])
    return radar_ln

ani = FuncAnimation(fig, animate, frames=len(data[0]), fargs=(radar_ln, label_loc, data), interval=40)
ani.save(str(np.random.random())+".mp4", dpi=300)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2219             try:
# -> 2220                 format = EXTENSION[ext]
#    2221             except KeyError as e:
#
# KeyError: '.mp4'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# /var/folders/p3/1_9sgz910vqfv2y4wq32r7q00000gn/T/ipykernel_7628/1380827370.py in <module>
#       4
#       5 ani = FuncAnimation(fig, animate, frames=len(data[0]), fargs=(radar_ln, label_loc, data), interval=40)
# ----> 6 ani.save(str(np.random.random())+".mp4", dpi=300)
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1175                         progress_callback(frame_number, total_frames)
#    1176                         frame_number += 1
# -> 1177                 writer.grab_frame(**savefig_kwargs)
#    1178
#    1179     def _step(self, *args):
#
# /opt/anaconda3/lib/python3.9/contextlib.py in __exit__(self, typ, value, traceback)
#     124         if typ is None:
#     125             try:
# --> 126                 next(self.gen)
#     127             except StopIteration:
#     128                 return False
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     236             yield self
#     237         finally:
# --> 238             self.finish()
#     239
#     240
#
# /opt/anaconda3/lib/python3.9/site-packages/matplotlib/animation.py in finish(self)
#     538
#     539     def finish(self):
# --> 540         self._frames[0].save(
#     541             self.outfile, save_all=True, append_images=self._frames[1:],
#     542             duration=int(1000 / self.fps), loop=0)
#
# /opt/anaconda3/lib/python3.9/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2220                 format = EXTENSION[ext]
#    2221             except KeyError as e:
# -> 2222                 raise ValueError(f"unknown file extension: {ext}") from e
#    2223
#    2224         if format.upper() not in SAVE:
#
# ValueError: unknown file extension: .mp4
